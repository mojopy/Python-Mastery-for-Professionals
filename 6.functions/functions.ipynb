# %%
def myfunction():
    print("This is from a fuction")

myfunction()

# %%
def add(x,y,z,p,w):
    print("x is %s, y is %s, z is %s, p is %s, w is %s" %(x,y,z,p,w))
    return x+y+z+p+w 
add(5,6,3,4,2)

# %%
def exampleFunction():
    x = 10
    print(x)
    if x ==10:
        print("my statement is true")

# %%
exampleFunction()

# %%
def calculate(x,y):
    print(x+y)

calculate(2,6)

# %%
calculate(4, 7)

# %%
def happy_bithday(name, age, case):
    print(f"Happy Birthday to you {name}!")
    print(f"You were {age} years old yesterday.")
    print(f"Congratulation, for your {case} years old!")
    if case >= 18:
        print(f"Hey, you {name} , you are mature!")
    elif case < 18:
        print(f"you,{name},you are not mature! Afere {18-case} year you will be mature!")
    print()
 
happy_bithday("opu", 21, 22)
happy_bithday("likhon", 12,13)
happy_bithday("Alice",17,18)
# Out:
# Happy Birthday to you opu!
# You were 21 years old yesterday.
# Congratulation, for your 22 years old!
# Hey, you opu , you are mature!
#
# Happy Birthday to you likhon!
# You were 12 years old yesterday.
# Congratulation, for your 13 years old!
# you,likhon,you are not mature! Afere 5 year you will be mature!
#
# Happy Birthday to you Alice!
# You were 17 years old yesterday.
# Congratulation, for your 18 years old!
# Hey, you Alice , you are mature!
