# %%
import requests

r = requests.get("https://xkcd.com/353/")
print(r.text)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <link rel="stylesheet" type="text/css" href="/s/7d94e0.css" title="Default"/>
# <title>xkcd: Python</title>
# <meta http-equiv="X-UA-Compatible" content="IE=edge"/>
# <link rel="shortcut icon" href="/s/919f27.ico" type="image/x-icon"/>
# <link rel="icon" href="/s/919f27.ico" type="image/x-icon"/>
# <link rel="alternate" type="application/atom+xml" title="Atom 1.0" href="/atom.xml"/>
# <link rel="alternate" type="application/rss+xml" title="RSS 2.0" href="/rss.xml"/>
# <!-- <script type="text/javascript" src="/s/b66ed7.js" async></script>
# <script type="text/javascript" src="/s/1b9456.js" async></script> -->
#
# <meta property="og:site_name" content="xkcd">
#
# <meta property="og:title" content="Python">
# <meta property="og:url" content="https://xkcd.com/353/">
# <meta property="og:image" content="https://imgs.xkcd.com/comics/python.png">
# <meta name="twitter:card" content="summary_large_image">
#
# </head>
# <body>
# <div id="topContainer">
# <div id="topLeft">
# <ul>
# <li><a href="/archive">Archive</a></li>
# <li><a href="https://what-if.xkcd.com">What If?</a></li>
# <li><a rel="author" href="/about">About</a></li>
# <li><a href="/atom.xml">Feed</a>&bull;<a href="/newsletter/">Email</a></li>
# <li><a href="https://twitter.com/xkcd/">TW</a>&bull;<a href="https://www.facebook.com/TheXKCD/">FB</a>&bull;<a href="https://www.instagram.com/xkcd/">IG</a></li>
# <li><a href="/books/">-Books-</a></li>
# <li><a href="/what-if-2/">What If? 2</a></li>
# <li><a href="/what-if/">WI?</a>&bull;<a href="/thing-explainer/">TE</a>&bull;<a href="/how-to/">HT</a></li>
# </ul>
# </div>
# <div id="topRight">
# <div id="masthead">
# <span><a href="/"><img src="/s/0b7742.png" alt="xkcd.com logo" height="83" width="185"/></a></span>
# <span id="slogan">A webcomic of romance,<br/> sarcasm, math, and language.</span>
# </div>
# <div id="news">
# <div id="xkcdNews">
# <a href="https://xkcd.com/what-if/">Special 10th anniversary edition of WHAT IF?</a>—revised and annotated with brand-new illustrations and answers to important questions you never thought to ask—coming from November 2024. Preorder <a href="https://bit.ly/WhatIf10th">here</a>!
# </div>
#
# </div>
# </div>
# <div id="bgLeft" class="bg box"></div>
# <div id="bgRight" class="bg box"></div>
# </div>
# <div id="middleContainer" class="box">
#
# <div id="ctitle">Python</div>
# <ul class="comicNav">
# <li><a href="/1/">|&lt;</a></li>
# <li><a rel="prev" href="/352/" accesskey="p">&lt; Prev</a></li>
# <li><a href="//c.xkcd.com/random/comic/">Random</a></li>
# <li><a rel="next" href="/354/" accesskey="n">Next &gt;</a></li>
# <li><a href="/">&gt;|</a></li>
# </ul>
# <div id="comic">
# <img src="//imgs.xkcd.com/comics/python.png" title="I wrote 20 short programs in Python yesterday.  It was wonderful.  Perl, I&#39;m leaving you." alt="Python"  style="image-orientation:none" />
# </div>
# <ul class="comicNav">
# <li><a href="/1/">|&lt;</a></li>
# <li><a rel="prev" href="/352/" accesskey="p">&lt; Prev</a></li>
# <li><a href="//c.xkcd.com/random/comic/">Random</a></li>
# <li><a rel="next" href="/354/" accesskey="n">Next &gt;</a></li>
# <li><a href="/">&gt;|</a></li>
# </ul>
# <br />
# Permanent link to this comic: <a href="https://xkcd.com/353">https://xkcd.com/353/</a><br />
# Image URL (for hotlinking/embedding): <a href= "https://imgs.xkcd.com/comics/python.png">https://imgs.xkcd.com/comics/python.png</a>
#
# <div id="transcript" style="display: none">[[ Guy 1 is talking to Guy 2, who is floating in the sky ]]
# Guy 1: You&#39;re flying! How?
# Guy 2: Python!
# Guy 2: I learned it last night! Everything is so simple!
# Guy 2: Hello world is just &#39;print &quot;Hello, World!&quot; &#39;
# Guy 1: I dunno... Dynamic typing? Whitespace?
# Guy 2: Come join us! Programming is fun again! It&#39;s a whole new world up here!
# Guy 1: But how are you flying?
# Guy 2: I just typed &#39;import antigravity&#39;
# Guy 1: That&#39;s it?
# Guy 2: ...I also sampled everything in the medicine cabinet for comparison.
# Guy 2: But i think this is the python.
# {{ I wrote 20 short programs in Python yesterday.  It was wonderful.  Perl, I&#39;m leaving you. }}</div>
# </div>
# <div id="bottom" class="box">
# <img src="//imgs.xkcd.com/s/a899e84.jpg" width="520" height="100" alt="Selected Comics" usemap="#comicmap"/>
# <map id="comicmap" name="comicmap">
# <area shape="rect" coords="0,0,100,100" href="/150/" alt="Grownups"/>
# <area shape="rect" coords="104,0,204,100" href="/730/" alt="Circuit Diagram"/>
# <area shape="rect" coords="208,0,308,100" href="/162/" alt="Angular Momentum"/>
# <area shape="rect" coords="312,0,412,100" href="/688/" alt="Self-Description"/>
# <area shape="rect" coords="416,0,520,100" href="/556/" alt="Alternative Energy Revolution"/>
# </map>
# <br />
# <a href="//xkcd.com/1732/"><img border=0 src="//imgs.xkcd.com/s/temperature.png" width="520" height="100" alt="Earth temperature timeline"></a>
# <br />
# <div>
# <!--
# Search comic titles and transcripts:
# <script type="text/javascript" src="//www.google.com/jsapi"></script>
# <script type="text/javascript">google.load('search', '1');google.setOnLoadCallback(function() {google.search.CustomSearchControl.attachAutoCompletion('012652707207066138651:zudjtuwe28q',document.getElementById('q'),'cse-search-box');});</script>
# <form action="//www.google.com/cse" id="cse-search-box">
# <div>
# <input type="hidden" name="cx" value="012652707207066138651:zudjtuwe28q"/>
# <input type="hidden" name="ie" value="UTF-8"/>
# <input type="text" name="q" id="q" size="31"/>
# <input type="submit" name="sa" value="Search"/>
# </div>
# </form>
# <script type="text/javascript" src="//www.google.com/cse/brand?form=cse-search-box&amp;lang=en"></script>
# -->
# <a href="/rss.xml">RSS Feed</a> - <a href="/atom.xml">Atom Feed</a> - <a href="/newsletter/">Email</a>
# </div>
# <br />
# <div id="comicLinks">
# Comics I enjoy:<br/>
#         <a href="http://threewordphrase.com/">Three Word Phrase</a>,
#         <a href="https://www.smbc-comics.com/">SMBC</a>,
#         <a href="https://www.qwantz.com">Dinosaur Comics</a>,
#         <a href="https://oglaf.com/">Oglaf</a> (nsfw),
#         <a href="https://www.asofterworld.com">A Softer World</a>,
#         <a href="https://buttersafe.com/">Buttersafe</a>,
#         <a href="https://pbfcomics.com/">Perry Bible Fellowship</a>,
#         <a href="https://questionablecontent.net/">Questionable Content</a>,
#         <a href="http://www.buttercupfestival.com/">Buttercup Festival</a>,
#         <a href="https://www.homestuck.com/">Homestuck</a>,
# 	<a href="https://www.jspowerhour.com/">Junior Scientist Power Hour</a>
# </div>
# <br />
# <div id="comicLinks">
# Other things:<br/>
#         <a href="https://medium.com/civic-tech-thoughts-from-joshdata/so-you-want-to-reform-democracy-7f3b1ef10597">Tips on technology and government</a>,<br />
#         <a href="https://www.nytimes.com/interactive/2017/climate/what-is-climate-change.html">Climate FAQ</a>,
# 	<a href="https://twitter.com/KHayhoe">Katharine Hayhoe</a>
# </div>
# <br />
# <center>
# <div id="footnote" style="width:70%">xkcd.com is best viewed with Netscape Navigator 4.0 or below on a Pentium 3&plusmn;1 emulated in Javascript on an Apple IIGS<br />at a screen resolution of 1024x1. Please enable your ad blockers, disable high-heat drying, and remove your device<br />from Airplane Mode and set it to Boat Mode. For security reasons, please leave caps lock on while browsing.</div>
# </center>
# <div id="licenseText">
# <p>
# This work is licensed under a
# <a href="https://creativecommons.org/licenses/by-nc/2.5/">Creative Commons Attribution-NonCommercial 2.5 License</a>.
# </p><p>
# This means you're free to copy and share these comics (but not to sell them). <a rel="license" href="/license.html">More details</a>.</p>
# </div>
# </div>
# </body>
# <!-- Layout by Ian Clasbey, davean, and chromakode -->
# </html>

# %%
import requests

r= requests.get("https://unsplash.com/photos/black-flat-screen-computer-monitor-8qEB0fTe9Vw")

print (r.content)



import requests

r= requests.get("https://unsplash.com/photos/black-flat-screen-computer-monitor-8qEB0fTe9Vw")

print (r.text)



import requests

r= requests.get("https://youtu.be/kqtD5dpn9C8?si=QUFdgd7Lh-egUDpk")

print(r.content)


import requests

r= requests.get("https://youtu.be/kqtD5dpn9C8?si=QUFdgd7Lh-egUDpk")

print(r.content)
# Out:
# b'<!DOCTYPE html><html lang="en-US"><head><title data-rh="true">Black flat screen computer monitor photo \xe2\x80\x93 Free Code Image on Unsplash</title><link data-rh="true" rel="apple-touch-icon" sizes="180x180" href="https://unsplash-assets.imgix.net/favicon/apple-touch-icon.png"/><link data-rh="true" rel="icon" type="image/png" sizes="32x32" href="https://unsplash-assets.imgix.net/favicon/favicon-32x32.png" media="(prefers-color-scheme: light)"/><link data-rh="true" rel="icon" type="image/png" sizes="16x16" href="https://unsplash-assets.imgix.net/favicon/favicon-16x16.png" media="(prefers-color-scheme: light)"/><link data-rh="true" rel="icon" type="image/png" sizes="32x32" href="https://unsplash-assets.imgix.net/favicon/favicon-32x32-dark-mode.png" media="(prefers-color-scheme: dark)"/><link data-rh="true" rel="icon" type="image/png" sizes="16x16" href="https://unsplash-assets.imgix.net/favicon/favicon-16x16-dark-mode.png" media="(prefers-color-scheme: dark)"/><link data-rh="true" rel="mask-icon" href="https://unsplash-assets.imgix.net/favicon/safari-pinned-tab.svg" color="#000000"/><link data-rh="true" rel="manifest" href="/site-v2.webmanifest"/><link data-rh="true" rel="canonical" href="https://unsplash.com/photos/black-flat-screen-computer-monitor-8qEB0fTe9Vw"/><link data-rh="true" rel="alternate" hrefLang="de" href="https://unsplash.com/de/fotos/schwarzer-flachbildschirm-8qEB0fTe9Vw"/><link data-rh="true" rel="alternate" hrefLang="en" href="https://unsplash.com/photos/black-flat-screen-computer-monitor-8qEB0fTe9Vw"/><link data-rh="true" rel="alternate" hrefLang="es" href="https://unsplash.com/es/fotos/monitor-de-computadora-de-pantalla-plana-negro-8qEB0fTe9Vw"/><link data-rh="true" rel="alternate" hrefLang="fr" href="https://unsplash.com/fr/photos/ecran-plat-noir-ecran-dordinateur-8qEB0fTe9Vw"/><link data-rh="true" rel="alternate" hrefLang="it" href="https://unsplash.com/it/foto/monitor-per-computer-a-schermo-piatto-nero-8qEB0fTe9Vw"/><link data-rh="true" rel="alternate" hrefLang="ja" href="https://unsplash.com/ja/%E5%86%99%E7%9C%9F/%E9%BB%92%E3%81%AE%E3%83%95%E3%83%A9%E3%83%83%E3%83%88%E3%82%B9%E3%82%AF%E3%83%AA%E3%83%BC%E3%83%B3%E3%82%B3%E3%83%B3%E3%83%94%E3%83%A5%E3%83%BC%E3%82%BF%E3%83%BC%E3%83%A2%E3%83%8B%E3%82%BF%E3%83%BC-8qEB0fTe9Vw"/><link data-rh="true" rel="alternate" hrefLang="ko" href="https://unsplash.com/ko/%EC%82%AC%EC%A7%84/%EB%B8%94%EB%9E%99-%ED%8F%89%EB%A9%B4-%EC%8A%A4%ED%81%AC%EB%A6%B0-%EC%BB%B4%ED%93%A8%ED%84%B0-%EB%AA%A8%EB%8B%88%ED%84%B0-8qEB0fTe9Vw"/><link data-rh="true" rel="alternate" hrefLang="pt" href="https://unsplash.com/pt-br/fotografias/monitor-de-computador-de-tela-plana-preta-8qEB0fTe9Vw"/><link data-rh="true" rel="alternate" hrefLang="x-default" href="https://unsplash.com/photos/black-flat-screen-computer-monitor-8qEB0fTe9Vw"/><meta data-rh="true" name="charset" content="UTF8"/><meta data-rh="true" name="viewport" content="width=device-width, initial-scale=1.0, minimal-ui"/><meta data-rh="true" name="mobile-web-app-capable" content="yes"/><meta data-rh="true" name="apple-mobile-web-app-capable" content="yes"/><meta data-rh="true" name="apple-mobile-web-app-title" content="Unsplash"/><meta data-rh="true" name="application-name" content="Unsplash"/><meta data-rh="true" name="author" content="Unsplash"/><meta data-rh="true" name="msapplication-config" content="browserconfig.xml"/><meta data-rh="true" name="msapplication-TileColor" content="#ffffff"/><meta data-rh="true" name="msapplication-TileImage" content="https://unsplash.com/mstile-144x144.png"/><meta data-rh="true" name="theme-color" content="#ffffff"/><meta data-rh="true" name="description" content="Download this free HD photo of code, coding, programming, and javascript in Kabul, Afghanistan by Mohammad Rahmani (@afgprogrammer)"/><meta data-rh="true" name="twitter:site" content="@unsplash"/><meta data-rh="true" name="twitter:title" content="Photo by Mohammad Rahmani on Unsplash"/><meta data-rh="true" name="twitter:description" cont ...
# <!DOCTYPE html><html lang="en-US"><head><title data-rh="true">Black flat screen computer monitor photo – Free Code Image on Unsplash</title><link data-rh="true" rel="apple-touch-icon" sizes="180x180" href="https://unsplash-assets.imgix.net/favicon/apple-touch-icon.png"/><link data-rh="true" rel="icon" type="image/png" sizes="32x32" href="https://unsplash-assets.imgix.net/favicon/favicon-32x32.png" media="(prefers-color-scheme: light)"/><link data-rh="true" rel="icon" type="image/png" sizes="16x16" href="https://unsplash-assets.imgix.net/favicon/favicon-16x16.png" media="(prefers-color-scheme: light)"/><link data-rh="true" rel="icon" type="image/png" sizes="32x32" href="https://unsplash-assets.imgix.net/favicon/favicon-32x32-dark-mode.png" media="(prefers-color-scheme: dark)"/><link data-rh="true" rel="icon" type="image/png" sizes="16x16" href="https://unsplash-assets.imgix.net/favicon/favicon-16x16-dark-mode.png" media="(prefers-color-scheme: dark)"/><link data-rh="true" rel="mask-icon" href="https://unsplash-assets.imgix.net/favicon/safari-pinned-tab.svg" color="#000000"/><link data-rh="true" rel="manifest" href="/site-v2.webmanifest"/><link data-rh="true" rel="canonical" href="https://unsplash.com/photos/black-flat-screen-computer-monitor-8qEB0fTe9Vw"/><link data-rh="true" rel="alternate" hrefLang="de" href="https://unsplash.com/de/fotos/schwarzer-flachbildschirm-8qEB0fTe9Vw"/><link data-rh="true" rel="alternate" hrefLang="en" href="https://unsplash.com/photos/black-flat-screen-computer-monitor-8qEB0fTe9Vw"/><link data-rh="true" rel="alternate" hrefLang="es" href="https://unsplash.com/es/fotos/monitor-de-computadora-de-pantalla-plana-negro-8qEB0fTe9Vw"/><link data-rh="true" rel="alternate" hrefLang="fr" href="https://unsplash.com/fr/photos/ecran-plat-noir-ecran-dordinateur-8qEB0fTe9Vw"/><link data-rh="true" rel="alternate" hrefLang="it" href="https://unsplash.com/it/foto/monitor-per-computer-a-schermo-piatto-nero-8qEB0fTe9Vw"/><link data-rh="true" rel="alternate" hrefLang="ja" href="https://unsplash.com/ja/%E5%86%99%E7%9C%9F/%E9%BB%92%E3%81%AE%E3%83%95%E3%83%A9%E3%83%83%E3%83%88%E3%82%B9%E3%82%AF%E3%83%AA%E3%83%BC%E3%83%B3%E3%82%B3%E3%83%B3%E3%83%94%E3%83%A5%E3%83%BC%E3%82%BF%E3%83%BC%E3%83%A2%E3%83%8B%E3%82%BF%E3%83%BC-8qEB0fTe9Vw"/><link data-rh="true" rel="alternate" hrefLang="ko" href="https://unsplash.com/ko/%EC%82%AC%EC%A7%84/%EB%B8%94%EB%9E%99-%ED%8F%89%EB%A9%B4-%EC%8A%A4%ED%81%AC%EB%A6%B0-%EC%BB%B4%ED%93%A8%ED%84%B0-%EB%AA%A8%EB%8B%88%ED%84%B0-8qEB0fTe9Vw"/><link data-rh="true" rel="alternate" hrefLang="pt" href="https://unsplash.com/pt-br/fotografias/monitor-de-computador-de-tela-plana-preta-8qEB0fTe9Vw"/><link data-rh="true" rel="alternate" hrefLang="x-default" href="https://unsplash.com/photos/black-flat-screen-computer-monitor-8qEB0fTe9Vw"/><meta data-rh="true" name="charset" content="UTF8"/><meta data-rh="true" name="viewport" content="width=device-width, initial-scale=1.0, minimal-ui"/><meta data-rh="true" name="mobile-web-app-capable" content="yes"/><meta data-rh="true" name="apple-mobile-web-app-capable" content="yes"/><meta data-rh="true" name="apple-mobile-web-app-title" content="Unsplash"/><meta data-rh="true" name="application-name" content="Unsplash"/><meta data-rh="true" name="author" content="Unsplash"/><meta data-rh="true" name="msapplication-config" content="browserconfig.xml"/><meta data-rh="true" name="msapplication-TileColor" content="#ffffff"/><meta data-rh="true" name="msapplication-TileImage" content="https://unsplash.com/mstile-144x144.png"/><meta data-rh="true" name="theme-color" content="#ffffff"/><meta data-rh="true" name="description" content="Download this free HD photo of code, coding, programming, and javascript in Kabul, Afghanistan by Mohammad Rahmani (@afgprogrammer)"/><meta data-rh="true" name="twitter:site" content="@unsplash"/><meta data-rh="true" name="twitter:title" content="Photo by Mohammad Rahmani on Unsplash"/><meta data-rh="true" name="twitter:description" content="
# “Talk is cheap. Show me the code.”
# ― Linus Torvalds – Download this photo by Mohammad Rahmani on Unsplash"/><meta data-rh="true" name="twitter:url" content="https://unsplash.com/photos/black-flat-screen-computer-monitor-8qEB0fTe9Vw"/><meta data-rh="true" name="twitter:card" content="summary_large_image"/><meta data-rh="true" name="twitter:image" content="https://images.unsplash.com/photo-1607799279861-4dd421887fb3?blend=000000&amp;blend-alpha=10&amp;blend-mode=normal&amp;blend-w=1&amp;crop=faces%2Cedges&amp;h=630&amp;mark=https%3A%2F%2Fimages.unsplash.com%2Fopengraph%2Flogo.png&amp;mark-align=top%2Cleft&amp;mark-pad=50&amp;mark-w=64&amp;w=1200&amp;auto=format&amp;fit=crop&amp;q=60&amp;ixid=M3wxMjA3fDB8MXxhbGx8fHx8fHx8fHwxNzIwMDcwMzM4fA&amp;ixlib=rb-4.0.3"/><meta data-rh="true" name="twitter:creator" content="@afgprogrammer"/><meta data-rh="true" property="og:title" content="Photo by Mohammad Rahmani on Unsplash"/><meta data-rh="true" property="og:description" content="
# “Talk is cheap. Show me the code.”
# ― Linus Torvalds – Download this photo by Mohammad Rahmani on Unsplash"/><meta data-rh="true" property="og:type" content="website"/><meta data-rh="true" property="og:url" content="https://unsplash.com/photos/black-flat-screen-computer-monitor-8qEB0fTe9Vw"/><meta data-rh="true" property="og:image" content="https://images.unsplash.com/photo-1607799279861-4dd421887fb3?blend=000000&amp;blend-alpha=10&amp;blend-mode=normal&amp;blend-w=1&amp;crop=faces%2Cedges&amp;h=630&amp;mark=https%3A%2F%2Fimages.unsplash.com%2Fopengraph%2Flogo.png&amp;mark-align=top%2Cleft&amp;mark-pad=50&amp;mark-w=64&amp;w=1200&amp;auto=format&amp;fit=crop&amp;q=60&amp;ixid=M3wxMjA3fDB8MXxhbGx8fHx8fHx8fHwxNzIwMDcwMzM4fA&amp;ixlib=rb-4.0.3"/><meta name="apple-itunes-app" content="app-id=1290631746"/><link type="application/opensearchdescription+xml" rel="search" href="/a/opensearch.xml"/><style data-href="/a/en-US/8547.dcc3aeb56950dbce2a17.css">/*! normalize.css v8.0.1 | MIT License | github.com/necolas/normalize.css */html{line-height:1.15;-webkit-text-size-adjust:100%}body{margin:0}main{display:block}h1{font-size:2em;margin:.67em 0}hr{box-sizing:initial;height:0;overflow:visible}pre{font-family:monospace,monospace;font-size:1em}a{background-color:initial}abbr[title]{border-bottom:none;text-decoration:underline;-webkit-text-decoration:underline dotted;text-decoration:underline dotted}b,strong{font-weight:bolder}code,kbd,samp{font-family:monospace,monospace;font-size:1em}small{font-size:80%}sub,sup{font-size:75%;line-height:0;position:relative;vertical-align:initial}sub{bottom:-.25em}sup{top:-.5em}img{border-style:none}button,input,optgroup,select,textarea{font-family:inherit;font-size:100%;line-height:1.15;margin:0}button,input{overflow:visible}button,select{text-transform:none}[type=button],[type=reset],[type=submit],button{-webkit-appearance:button}[type=button]::-moz-focus-inner,[type=reset]::-moz-focus-inner,[type=submit]::-moz-focus-inner,button::-moz-focus-inner{border-style:none;padding:0}[type=button]:-moz-focusring,[type=reset]:-moz-focusring,[type=submit]:-moz-focusring,button:-moz-focusring{outline:1px dotted ButtonText}fieldset{padding:.35em .75em .625em}legend{box-sizing:border-box;color:inherit;display:table;max-width:100%;padding:0;white-space:normal}progress{vertical-align:initial}textarea{overflow:auto}[type=checkbox],[type=radio]{box-sizing:border-box;padding:0}[type=number]::-webkit-inner-spin-button,[type=number]::-webkit-outer-spin-button{height:auto}[type=search]{-webkit-appearance:textfield;outline-offset:-2px}[type=search]::-webkit-search-decoration{-webkit-appearance:none}::-webkit-file-upload-button{-webkit-appearance:button;font:inherit}details{display:block}summary{display:list-item}[hidden],template{display:none}::view-transition-old(root){display:none}::view-transition-new(root){animation:none}:focus:not(:focus-visible){outline:none}#app,body,html{height:100%}body{font-family:-apple-system,BlinkMacSystemFont,San Francisco,Helvetica Neue,Helvetica,Ubuntu,Roboto,Noto,Segoe UI,Arial,sans-serif;font-size:15px;font-weight:400;line-height:1.6}*{box-sizing:border-box}.oLkUH,a{color:var(--link-text-color);transition:color .1s ease-in-out,opacity .1s ease-in-out;-webkit-text-decoration-skip:ink;text-decoration-skip-ink:auto}:is(.I3Ayg,a):hover{color:var(--link-text-color-hover)}.EcTAd{text-decoration:underline}p{margin:16px 0}blockquote,figure,q{margin:0}img{vertical-align:middle}input{letter-spacing:inherit}button{color:inherit;cursor:pointer}button:disabled{cursor:unset}button,input,optgroup,select,textarea{line-height:inherit}kbd{border:1px solid #d1d1d1;border-radius:3px;box-shadow:0 1px 1px #0000001a;padding:1px 4px}h1,h2,h3,h4,h5,h6{font-size:inherit;font-weight:inherit;margin-block:0}.ReactModal__Body--open{overflow:hidden}.t06TV{display:inline}.TB6qM{display:block}.sm61c{display:inline-block}.iYA3Y{display:table}.tsKQF{display:table-cell}.RE6CB{overflow:hidden}.VdqdN{overflow:scroll}.ewuAy{overflow:auto}.VXveO:after,.VXveO:before{c ...
#       --spacer-h-md,var(--spacer-h-sm,var(--spacer-h-xs,var(--spacer-h-xxs)))
#     );width:var(
#       --spacer-w-md,var(--spacer-w-sm,var(--spacer-w-xs,var(--spacer-w-xxs)))
#     )}}@media (min-width:1200px){.x2Dxg{height:var(
#       --spacer-h-lg,var(
#         --spacer-h-md,var(--spacer-h-sm,var(--spacer-h-xs,var(--spacer-h-xxs)))
#       )
#     );width:var(
#       --spacer-w-lg,var(
#         --spacer-w-md,var(--spacer-w-sm,var(--spacer-w-xs,var(--spacer-w-xxs)))
#       )
#     )}}.ogSND{border:1px solid #0000;border-radius:6px;display:inline-block;text-align:center;text-decoration:none;transition:all .1s ease-in-out;-webkit-user-select:none;user-select:none;white-space:nowrap;fill:currentColor}button.ogSND[disabled]{background:#eee;border-color:#0000;color:#767676;cursor:not-allowed}.szXtT:focus-visible{outline-offset:4px}.Qzy6N{box-shadow:0 1px 1px #00000014}.mP89P:hover{box-shadow:0 1px 2px #0000001a}.vpYIZ{align-items:center;border-radius:3px;display:inline-flex;line-height:1;padding:4px 6px}.xMiih{height:32px;justify-content:center;line-height:30px;padding-inline:11px}.ibgtd{font-size:15px;height:44px;line-height:42px;padding-inline:16px}.iZOSJ{font-size:18px;height:56px;line-height:54px;padding-inline:24px}.aovXH{background:#eee;color:#767676;cursor:not-allowed}.y9t2i:hover{box-shadow:inherit}.IUoDf{background:linear-gradient(to top,#0000 50%,var(--button-primary-gradient-background-color) 100%),var(--button-primary-background-color);color:var(--button-primary-text-color)}.LoCAy:hover{background:linear-gradient(to top,#0000 50%,var(--button-primary-gradient-background-color) 100%),var(--button-primary-background-color-hover);color:var(--button-primary-text-color)}.LaaWe{background:linear-gradient(180deg,#0000 50%,#0a141e05),#fff;border-color:#d1d1d1;color:#767676}.v2BPu:hover{border-color:#767676}.v2BPu:focus,.v2BPu:hover{color:#111}.NONej{border:unset;color:#555;fill:currentColor;box-shadow:0 1px 2px #0000001a;min-width:40px}.UvzWP{background:linear-gradient(180deg,#0000 50%,#0a141e0f),#f6f6f6fa}.UvzWP:hover{color:#111;fill:currentColor;background:linear-gradient(180deg,#0000 50%,#0a141e0f),#fff;box-shadow:0 1px 1px #0000000d,0 1px 3px #0003}.y1fNt{background:linear-gradient(180deg,#0000 50%,#0a141e14),#3cb46e;color:#fff}.CV5x5:hover{background:linear-gradient(180deg,#0000 50%,#0a141e17),#37a866;color:#fff}.E1x15{background:linear-gradient(180deg,#0000 50%,#0a141e14),#e25c3d;color:#fff}.zTpB8:hover{background:linear-gradient(180deg,#0000 50%,#0a141e17),#df4927;color:#fff}.FbKNm{background:linear-gradient(180deg,#0000 50%,#0a141e14),#007fff;color:#fff}.nhHsY:focus,.nhHsY:hover{background:linear-gradient(180deg,#0000 50%,#0a141e17),#006aff;color:#fff}.S_u_F{background:linear-gradient(180deg,#0000 50%,rgba(10,20,30,.025)),#fff;color:#111}.tmK_y:focus,.tmK_y:hover{background:linear-gradient(180deg,#0000 50%,rgba(10,20,30,.045)),#f5f5f5;color:#111}.U5646{color:#767676;line-height:16px;padding:7px 11px}.GtKJI:hover{color:#111}.ioDGC{background-color:#fff;border:1px solid #d1d1d1;border-radius:6px;min-height:40px;transition:border-color .1s ease-in-out}.ioDGC:focus-within{outline:5px auto Highlight;outline:5px auto -webkit-focus-ring-color}.AeE_N:focus-within,.AeE_N:hover{border-color:#767676}.X3eFA{cursor:not-allowed}.CoQFw{background-color:#f5f5f5;border-color:#d1d1d1}.ffHip{background-image:none;padding:6px 12px;vertical-align:middle;width:100%}.ApR0P{line-height:1.5}.SEQu6{position:relative}.prf1f{bottom:10px;color:#767676;pointer-events:none;position:absolute;right:10px}.DOxA_{align-items:stretch;display:flex}.l0L9t{align-items:center;display:flex}.E_rOL{box-sizing:initial;padding-left:8px;transition:fill .1s ease-in-out;fill:#d1d1d1}.kvVay{display:flex;flex-grow:1}.ch4ws{box-sizing:border-box;flex-grow:1;padding-left:6px}.ch4ws:focus{outline:none}.fIyWG{color:#767676}.y8Be6{display:grid;grid-template-columns:auto minmax(0,1fr);grid-gap:4px 8px}.GTPhI,.JIO4h{cursor:pointer}.Pyzvt,.piHSV{color:#767676;cursor:not-allowed}.VBCNC{align-self:center}.knWDG,.pTkwf{grid-column:2;grid-row:2}.d4H9V{padding-right:27px}.Bmt89{-webkit-appearance:none;appearance:none;background:#0000;background-image:url("data:image/svg+xml;charset=utf-8,%3Csvg xmlns='http://www.w3.org/2000/svg' width='24' height='24' fill='gray'%3E%3Cpath d='m0 6 12 12L24 6z'/%3E%3Cpath fill='none' d='M0 0h24v24H0z'/%3E%3C/svg%3E");background-position:right 12px top 50%;background-repeat:no-repeat;background-size:10px;line-height:24px}.B ...
# LUX=(function(){var a=("undefined"!==typeof(LUX)&&"undefined"!==typeof(LUX.gaMarks)?LUX.gaMarks:[]);var d=("undefined"!==typeof(LUX)&&"undefined"!==typeof(LUX.gaMeasures)?LUX.gaMeasures:[]);var j="LUX_start";var k=window.performance;var l=("undefined"!==typeof(LUX)&&LUX.ns?LUX.ns:(Date.now?Date.now():+(new Date())));if(k&&k.timing&&k.timing.navigationStart){l=k.timing.navigationStart}function f(){if(k&&k.now){return k.now()}var o=Date.now?Date.now():+(new Date());return o-l}function b(n){if(k){if(k.mark){return k.mark(n)}else{if(k.webkitMark){return k.webkitMark(n)}}}a.push({name:n,entryType:"mark",startTime:f(),duration:0});return}function m(p,t,n){if("undefined"===typeof(t)&&h(j)){t=j}if(k){if(k.measure){if(t){if(n){return k.measure(p,t,n)}else{return k.measure(p,t)}}else{return k.measure(p)}}else{if(k.webkitMeasure){return k.webkitMeasure(p,t,n)}}}var r=0,o=f();if(t){var s=h(t);if(s){r=s.startTime}else{if(k&&k.timing&&k.timing[t]){r=k.timing[t]-k.timing.navigationStart}else{return}}}if(n){var q=h(n);if(q){o=q.startTime}else{if(k&&k.timing&&k.timing[n]){o=k.timing[n]-k.timing.navigationStart}else{return}}}d.push({name:p,entryType:"measure",startTime:r,duration:(o-r)});return}function h(n){return c(n,g())}function c(p,o){for(i=o.length-1;i>=0;i--){var n=o[i];if(p===n.name){return n}}return undefined}function g(){if(k){if(k.getEntriesByType){return k.getEntriesByType("mark")}else{if(k.webkitGetEntriesByType){return k.webkitGetEntriesByType("mark")}}}return a}return{mark:b,measure:m,gaMarks:a,gaMeasures:d}})();LUX.ns=(Date.now?Date.now():+(new Date()));LUX.ac=[];LUX.cmd=function(a){LUX.ac.push(a)};LUX.init=function(){LUX.cmd(["init"])};LUX.send=function(){LUX.cmd(["send"])};LUX.addData=function(a,b){LUX.cmd(["addData",a,b])};LUX_ae=[];window.addEventListener("error",function(a){LUX_ae.push(a)});LUX_al=[];if("function"===typeof(PerformanceObserver)&&"function"===typeof(PerformanceLongTaskTiming)){var LongTaskObserver=new PerformanceObserver(function(c){var b=c.getEntries();for(var a=0;a<b.length;a++){var d=b[a];LUX_al.push(d)}});try{LongTaskObserver.observe({type:["longtask"]})}catch(e){}};
# LUX.label = 'Asset';
# </script><script>window.__TRACKING__ = {};</script><style>.styles-module_fontWeightMedium__8Gcvf{font-weight:500}.styles-module_resetBtn__rK1p9{background-color:initial;border:none;font-weight:inherit;padding:0;text-align:inherit}.styles-module_small__Ipy6s{font-size:14px;height:32px;line-height:30px;padding-inline:11px}.styles-module_base__tbRd1{fill:currentColor;border:1px solid #0000;border-radius:4px;display:inline-block;text-align:center;text-decoration:none;transition:all .1s ease-in-out;-webkit-user-select:none;user-select:none;white-space:nowrap}button.styles-module_base__tbRd1[disabled]{background-color:#eee;border-color:#0000;color:#767676;cursor:not-allowed}.styles-module_baseWithShadow__MD3Pj{box-shadow:0 1px 1px #0000000a}.styles-module_baseWithShadowInteractive__SeEXS:hover{box-shadow:0 1px 2px #00000014}.styles-module_primary__VnfNl{background-color:#111;color:#fff}.styles-module_primaryInteractive__aH-uc:hover{color:#fff}.styles-module_outline__HamSs{background-color:#fff;border-color:#d1d1d1;color:#767676}.styles-module_outlineInteractive__1affc:hover{border-color:#767676}.styles-module_outlineInteractive__1affc:focus,.styles-module_outlineInteractive__1affc:hover{color:#111}.styles-module_dialog__qMeos{border:unset;display:none;font-size:14px;margin:unset}.styles-module_dialog__qMeos[open]{display:block}@media (max-width:767px){.styles-module_dialog__qMeos{background-color:#f5f5f5;padding:12px;position:relative}}@media (min-width:768px){.styles-module_dialog__qMeos{background-color:#fff;border-radius:8px;bottom:20px;box-shadow:0 8px 16px 0 #00000029;left:20px;padding:24px;position:fixed;width:480px;z-index:6}}.styles-module_closeButton__hbqbL{fill:#767676;align-items:center;display:flex;height:40px;justify-content:center;position:absolute;right:0;top:0;width:40px}.styles-module_closeButton__hbqbL:hover{fill:#111}.styles-module_closeIcon__g8YH1{height:24px;transition:fill .1s ease-in-out;width:24px}.styles-module_content__IZ0A3{margin-top:0}@media (min-width:768px){.styles-module_content__IZ0A3{padding-right:8px}}@media (max-width:767px){.styles-module_content__IZ0A3{padding-right:24px}}.styles-module_buttonContainer__LHjZk{display:flex;flex-wrap:wrap;gap:8px}@media (max-width:767px){.styles-module_buttonContainer__LHjZk{margin-top:16px}}@media (min-width:768px){.styles-module_buttonContainer__LHjZk{margin-top:24px}}.styles-module_button__66CVU{flex-grow:1;min-width:calc(50% - 4px)}</style><script>
#               window.__UNSPLASH__ = { consent: { tag: 'NotRequired' } };
#             </script><script data-cookie-policy-href="/cookies" data-manage-consent-href="/cookies#manage-consent">!function(){"use strict";const e=3456e4,t="consent_uid",o=e=>document.cookie.split("; ").find((t=>t.startsWith(`${e}=`)))?.split("=")?.[1],s=(e,t,o)=>{document.cookie=[[e,t],...void 0!==o?[["max-age",o.toString()]]:[],["path","/"]].map((e=>e.join("="))).join("; ")},n=(c=e=>JSON.parse(e),e=>void 0===e?void 0:c(e));var c;const l=(e,t)=>{try{return e()}catch(e){return t}},i=(n,c)=>{const l=o(t),i=l??crypto.randomUUID();void 0===l&&s(t,i,e);return((e,t)=>{const o=Date.now().toString(),s={schema:"iglu:com.snowplowanalytics.snowplow/payload_data/jsonschema/1-0-4",data:[{...void 0!==e.category&&{se_ca:e.category},...void 0!==e.action&&{se_ac:e.action},...void 0!==e.label&&{se_la:e.label},...void 0!==e.property&&{se_pr:e.property},...void 0!==e.value&&{se_va:e.value.toString()},e:"se",eid:crypto.randomUUID(),tna:t.name,tv:"fetch",p:"web",cs:"UTF-8",dtm:o,duid:t.domainUserId,url:window.location.href,stm:o}]};return fetch(t.url,{method:"POST",headers:{"Content-Type":"application/json"},referrerPolicy:"no-referrer",body:JSON.stringify(s)}).catch((e=>e))})({category:"consent",action:n,label:c?"granted":"denied"},{domainUserId:i,name:"web-fetch",url:"https://collector.unsplash.com/com.snowplowanalytics.snowplow/tp2"})};var a="styles-module_dialog__qMeos";const r=document.currentScript.dataset,d=r.cookiePolicyHref,_=r.manageConsentHref,u=r.className;(()=>{const c=o(t);void 0!==c&&s(t,c,e);if(l((()=>!0===n(o("require_cookie_consent"))),!1)){const e=l((()=>n(o("cookie_consent"))),void 0),t=(e,t)=>i(e,t).then((e=>{if(e instanceof Error){const t=e;return console.error("Failed to store consent",t),s("cookie_consent",(!1).toString()),!1}return s("cookie_consent",t.toString(),15552e3),t})),c=(e,o)=>t(e,o).then((()=>window.location.reload()));if("boolean"==typeof e)window.__UNSPLASH__={consent:{tag:"Obtained",value:e,setConsent:c}};else{const{promise:e,resolve:o}=(()=>{let e;return{promise:new Promise((t=>{e=t})),resolve:e}})();let s=!0;window.__UNSPLASH__={consent:{tag:"Pending",value:()=>e,setConsent:(e,n)=>s?(s=!1,t(e,n).then((e=>o(e)))):c(e,n)}}}}else window.__UNSPLASH__={consent:{tag:"NotRequired"}}})(),requestAnimationFrame((()=>((e,t,o)=>{const s=window.__UNSPLASH__.consent;if("Pending"===s.tag){const c=function(e,t){for(var o=arguments.length,s=new Array(o>2?o-2:0),n=2;n<o;n++)s[n-2]=arguments[n];const c=document.createElement(e);Object.assign(c,t);for(const e of s)c.appendChild("string"==typeof e?document.createTextNode(e):e);return c},l="http://www.w3.org/2000/svg",i=document.createElementNS(l,"path");i.setAttribute("d","M19 6.41 17.59 5 12 10.59 6.41 5 5 6.41 10.59 12 5 17.59 6.41 19 12 13.41 17.59 19 19 17.59 13.41 12 19 6.41Z");const r=document.createElementNS(l,"desc");r.appendChild(document.createTextNode("A X shape"));const d=document.createElementNS(l,"svg");d.setAttribute("aria-hidden","false"),d.classList.add("styles-module_closeIcon__g8YH1"),d.setAttribute("width","32px"),d.setAttribute("height","32px"),d.setAttribute("version","1.1"),d.setAttribute("viewbox","0 0 24 24"),d.appendChild(r),d.appendChild(i);const _=c("button",{className:"styles-module_closeButton__hbqbL styles-module_resetBtn__rK1p9",title:"Close"},d),u=c("p",{className:"styles-module_content__IZ0A3",innerHTML:(n={link:t=>c("a",{href:e,innerText:t}).outerHTML},`Unsplash uses cookies and similar technologies to secure our site, provide useful features to free and paying users, and to ensure optimal performance. By clicking "Accept all cookies" or closing this prompt, you consent to the use of all cookies. By clicking "Accept essential only", you consent only to the use of cookies that are strictly necessary for the site to function. See our ${n.link("Cookie Policy")} for more info.`)}),m=c("a",{href:t},"Manage cookies"),y=c("button",{type:"button",className:"styles-module_objectButton__CGCdd styles-module_button__66CVU styles-module_outline__HamSs styl ...
# </script><script>
# (() => {
#   var addEventListener = Node.prototype.addEventListener;
#   Node.prototype.addEventListener = function(type) {
#     if (type === "wheel") {
#       return;
#     }
#     return addEventListener.apply(this, arguments);
#   };
# })();
# </script><script src="https://www.googletagmanager.com/gtag/js?id=G-21SLH4J369" defer=""></script><script>window.dataLayer = window.dataLayer || []; function gtag() { dataLayer.push(arguments); } gtag('js', new Date());</script><script data-tag-id="G-21SLH4J369" data-container-id="21SLH4J369" data-cookie-domain=".unsplash.com" data-secure="true">(()=>{
#     // biome-ignore lint/style/noNonNullAssertion: It'll be a non-module script.
#     const script = document.currentScript;
#     const params = script.dataset;
#     const containerId = params.containerId;
#     const tagId = params.tagId;
#     const cookieDomain = params.cookieDomain;
#     const secure = params.secure !== 'false';
#     const deleteCookie = (name)=>{
#         document.cookie = `${name}=; max-age=0; domain=${cookieDomain}; path=/`;
#     };
#     const unsplashConsent = window.__UNSPLASH__.consent;
#     const canSetCookie = unsplashConsent.tag === 'Obtained' && unsplashConsent.value || unsplashConsent.tag === 'NotRequired';
#     const defaultConsent = canSetCookie ? 'granted' : 'denied';
#     if (canSetCookie === false) {
#         // We manually remove cookies set by Google Analytics 4 if consent is pending
#         // or if it has been denied because denying consent doesn't delete them.
#         // https://support.google.com/analytics/answer/11397207?hl=en
#         deleteCookie('_ga');
#         deleteCookie(`_ga_${containerId}`);
#     }
#     gtag('consent', 'default', {
#         ad_storage: defaultConsent,
#         analytics_storage: defaultConsent,
#         functionality_storage: 'denied',
#         personalization_storage: 'denied',
#         security_storage: 'denied'
#     });
#     gtag('config', tagId, {
#         // eslint-disable-next-line local/no-array-methods
#         cookie_flags: [
#             ...secure ? [
#                 'secure'
#             ] : [],
#             'samesite=lax'
#         ].join('; ')
#     });
#     if (unsplashConsent.tag === 'Pending') {
#         void unsplashConsent.value().then((consent)=>{
#             if (consent) {
#                 gtag('consent', 'update', {
#                     ad_storage: 'granted',
#                     analytics_storage: 'granted'
#                 });
#             }
#         });
#     }
# })();
# </script></head><body><div id="app"><!--$--><div class="UadEE H8pLI be6tD"><div><div><div class="wCHN_"></div><!--$--><header class="VzhF5"><nav class="k13Nq _UNLg"><a class="tqhQ0 SfGU7" title="Home — Unsplash" href="/"><svg class="ayR4i uFlu6" width="32" height="32" viewBox="0 0 32 32" version="1.1" aria-labelledby="unsplash-home" aria-hidden="false"><desc lang="en-US">Unsplash logo</desc><title id="unsplash-home">Unsplash Home</title><path d="M10 9V0h12v9H10zm12 5h10v18H0V14h10v9h12v-9z"></path></svg></a><!--$--><div style="flex-shrink:0;--spacer-w-xxs:16px;--spacer-w-xs:16px;--spacer-w-sm:16px;--spacer-w-md:16px;--spacer-w-lg:16px" class="x2Dxg"></div><div class="yI7xY"><!--$--><form class="mUrIA uW0ft l1RkE OiMzP GcCli CfXP8" data-test="nav-bar-search-form-form" method="get" role="search" aria-label="Find visuals sitewide" action="/s"><button data-test="nav-bar-search-form-button" title="Search Unsplash" class="jp3Ix cs1e4" type="submit"><svg class="tciJv F6x3M WBypi" width="24" height="24" viewBox="0 0 24 24" version="1.1" aria-hidden="false"><desc lang="en-US">A magnifying glass</desc><path d="M16.5 15c.9-1.2 1.5-2.8 1.5-4.5C18 6.4 14.6 3 10.5 3S3 6.4 3 10.5 6.4 18 10.5 18c1.7 0 3.2-.5 4.5-1.5l4.6 4.5 1.4-1.5-4.5-4.5zm-6 1c-3 0-5.5-2.5-5.5-5.5S7.5 5 10.5 5 16 7.5 16 10.5 13.5 16 10.5 16z"></path></svg></button><div role="combobox" aria-haspopup="listbox" aria-owns="react-autowhatever-1" aria-expanded="false" class="GD0YC HkdlG"><input type="search" autoComplete="off" aria-autocomplete="list" aria-controls="react-autowhatever-1" style="-webkit-appearance:none" name="searchKeyword" placeholder="Search photos and illustrations" title="Search Unsplash" class="qoZU7 XhqG0" data-test="nav-bar-search-form-input" autoCapitalize="none" spellcheck="false" required="" value=""/><div id="react-autowhatever-1" role="listbox" class="jHhYy"></div></div></form><div class="eJvto"><div style="flex-shrink:0;--spacer-w-xxs:16px;--spacer-w-xs:16px;--spacer-w-sm:16px;--spacer-w-md:16px;--spacer-w-lg:16px" class="x2Dxg"></div><div class="NKrLq"><a class="wcgxB ogSND ZR5jm cs1e4 oLkUH xMiih ZR5jm GcCli iHTme I3Ayg" rel="nofollow" href="/login?referrer=%2Fphotos%2Fblack-flat-screen-computer-monitor-8qEB0fTe9Vw">Log in</a><button type="button" class="LaaWe Qzy6N ogSND ZR5jm cs1e4 xMiih ZR5jm GcCli v2BPu mP89P szXtT">Submit an image</button></div></div><div class="wMSzv"><div style="flex-shrink:0;--spacer-w-xxs:16px;--spacer-w-xs:16px;--spacer-w-sm:16px;--spacer-w-md:16px;--spacer-w-lg:16px" class="x2Dxg"></div><ul class="qnsDi GxtYC N46Vv"><li class="BpoxV Ps6wV"><a class="vyi25 ZR5jm GcCli o6a8N" href="/explore">Explore</a><ul class="eVrml qdEzU GxtYC N46Vv"><div class="fQqHM"><div class="dYbbM rkTjo"></div><div class="_s44w"></div></div><li><a class="D6QX4 vyi25 ZR5jm GcCli o6a8N" href="/images">Images</a></li><li><a class="D6QX4 vyi25 ZR5jm GcCli o6a8N" href="/backgrounds">Backgrounds</a></li><li><a class="D6QX4 vyi25 ZR5jm GcCli o6a8N" href="/wallpapers">Wallpapers</a></li></ul></li><li class="BpoxV"><a class="vyi25 ZR5jm GcCli o6a8N" href="/advertise"><div>Advertise</div></a></li><li class="BpoxV"><a class="a8GH7 vyi25 ZR5jm GcCli o6a8N" href="/plus">Get Unsplash+</a></li></ul><div style="flex-shrink:0;--spacer-w-xxs:16px;--spacer-w-xs:16px;--spacer-w-sm:16px;--spacer-w-md:16px;--spacer-w-lg:16px" class="x2Dxg"></div><div class="pcppf"></div><div style="flex-shrink:0;--spacer-w-xxs:20px;--spacer-w-xs:20px;--spacer-w-sm:20px;--spacer-w-md:20px;--spacer-w-lg:20px" class="x2Dxg"></div><div class="NKrLq"><a class="wcgxB ogSND ZR5jm cs1e4 oLkUH xMiih ZR5jm GcCli iHTme I3Ayg" rel="nofollow" href="/login?referrer=%2Fphotos%2Fblack-flat-screen-computer-monitor-8qEB0fTe9Vw">Log in</a><button type="button" class="LaaWe Qzy6N ogSND ZR5jm cs1e4 xMiih ZR5jm GcCli v2BPu mP89P szXtT">Submit an image</button></div></div><!--/$--></div><div style="flex-shrink:0;--spacer-w-xxs:16px;--spacer-w-xs:16px;--spacer-w-sm:16px;--spacer-w-md:16px;--spacer-w-lg:16px"  ...
# “Talk is cheap. Show me the code.”
# ― Linus Torvalds</p></div></div><div style="flex-shrink:0;--spacer-h-xxs:24px;--spacer-h-xs:24px;--spacer-h-sm:24px;--spacer-h-md:24px;--spacer-h-lg:24px" class="x2Dxg"></div><div class="EU15N"><div class="p9_Ov"><a class="iByl1 TOyBu SfGU7" href="/s/photos/Kabul%2C-Afghanistan"><span class="FCwRH"><svg class="bZ1i1" width="16" height="16" viewBox="0 0 24 24" version="1.1" aria-hidden="false"><desc lang="en-US">A map marker</desc><path d="M17.6 4.2C16 2.7 14.1 2 12 2s-4 .7-5.6 2.2C4.8 5.7 4 7.7 4 10.2c0 1.7.7 3.5 2 5.4 1.3 2 3.3 4.1 6 6.4 2.7-2.3 4.7-4.4 6-6.4 1.3-2 2-3.8 2-5.4 0-2.5-.8-4.5-2.4-6zm-1.1 10.1c-1 1.5-2.5 3.2-4.5 5.1-2-1.9-3.5-3.6-4.5-5.1-1-1.5-1.5-2.9-1.5-4.1 0-1.8.6-3.3 1.7-4.5C8.9 4.6 10.3 4 12 4s3.1.6 4.3 1.7c1.2 1.2 1.7 2.6 1.7 4.5 0 1.2-.5 2.5-1.5 4.1zm-2-4.3c0 1.4-1.1 2.5-2.5 2.5S9.5 11.4 9.5 10s1.1-2.5 2.5-2.5 2.5 1.1 2.5 2.5z"></path></svg><span class="jU5nt GcCli wP5Cw FEdrY">Kabul, Afghanistan</span></span></a></div><span class="FCwRH"><svg class="bZ1i1" width="16" height="16" viewBox="0 0 24 24" version="1.1" aria-hidden="false"><desc lang="en-US">Calendar outlined</desc><path d="M21 6v14c0 1.1-.9 2-2 2H5c-1.1 0-2-.9-2-2V6c0-1.1.9-2 2-2h1V2h2v2h8V2h2v2h1c1.1 0 2 .9 2 2zM5 8h14V6H5v2zm14 12V10H5v10h14z"></path></svg><span class="jU5nt GcCli"><span>Published on <time dateTime="2020-12-12T18:55:58.000Z" title="December 12, 2020 at 6:55:58 PM UTC">December 12, 2020 (UTC)</time></span></span></span><span class="FCwRH"><svg class="bZ1i1" width="16" height="16" viewBox="0 0 24 24" version="1.1" aria-hidden="false"><desc lang="en-US">Camera</desc><path d="m14.12 4 1.83 2H20v12H4V6h4.05l1.83-2h4.24ZM15 2H9L7.17 4H4c-1.1 0-2 .9-2 2v12c0 1.1.9 2 2 2h16c1.1 0 2-.9 2-2V6c0-1.1-.9-2-2-2h-3.17L15 2Zm-3 7c1.65 0 3 1.35 3 3s-1.35 3-3 3-3-1.35-3-3 1.35-3 3-3Zm0-2c-2.76 0-5 2.24-5 5s2.24 5 5 5 5-2.24 5-5-2.24-5-5-5Z"></path></svg><span class="jU5nt GcCli"><span class="i_yon">SONY, ILCE-7RM4<div style="display:inline"></div></span></span></span><span class="FCwRH"><svg class="bZ1i1" width="16" height="16" viewBox="0 0 24 24" version="1.1" aria-hidden="false"><desc lang="en-US">Safety</desc><path d="m10 14.2 6.6-6.6L18 9l-8 8-4-4 1.4-1.4 2.6 2.6ZM21 5v6c0 5.5-3.8 10.7-9 12-5.2-1.3-9-6.5-9-12V5l9-4 9 4Zm-2 1.3-7-3.1-7 3.1V11c0 4.5 3 8.7 7 9.9 4-1.2 7-5.4 7-9.9V6.3Z"></path></svg><span class="jU5nt GcCli">Free to use under the <a class="TOyBu SfGU7" href="/license">Unsplash License</a></span></span></div></div><div style="flex-shrink:0;--spacer-h-xxs:32px;--spacer-h-xs:32px;--spacer-h-sm:32px;--spacer-h-md:32px;--spacer-h-lg:32px" class="x2Dxg"></div><div class="zDHt2 N9mmz"><a class="VyS40 GcCli p4rnw" title="code images" href="/s/photos/code">code</a><a class="VyS40 GcCli p4rnw" title="coding images" href="/s/photos/coding">coding</a><a class="VyS40 GcCli p4rnw" title="programming images" href="/s/photos/programming">programming</a><a class="VyS40 GcCli p4rnw" title="javascript images" href="/s/photos/javascript">javascript</a><a class="VyS40 GcCli p4rnw" title="computer engineer images" href="/s/photos/computer-engineer">computer engineer</a><a class="VyS40 GcCli p4rnw" title="afghanistan images" href="/s/photos/afghanistan">afghanistan</a><a class="VyS40 GcCli p4rnw" title="coder images" href="/s/photos/coder">coder</a><a class="VyS40 GcCli p4rnw" title="kabul images" href="/s/photos/kabul">kabul</a><a class="VyS40 GcCli p4rnw" title="HD Screen Wallpapers" href="/wallpapers/screen">HD Screen Wallpapers</a><a class="VyS40 GcCli p4rnw" title="php images" href="/s/photos/php">php</a><a class="VyS40 GcCli p4rnw" title="vue.js images" href="/s/photos/vue.js">vue.js</a><a class="VyS40 GcCli p4rnw" title="developer life images" href="/s/photos/developer-life">developer life</a><a class="VyS40 GcCli p4rnw" title="macbook pro images" href="/s/photos/macbook-pro">macbook pro</a><a class="VyS40 GcCli p4rnw" title="software images" href="/s/photos/software">software</a><a class="VyS40 GcCli p4rnw" title="visual studio code images" h ...
# (function () {
# var NAVIGATION_START = "navigationStart";
#
# function getMeasureName(markEnd) {
#   return [NAVIGATION_START, markEnd].join('-');
# }
#
# function createOnLoadListener(markEnd) {
#   return function() {
#     var performance = window.performance;
#     if (performance && performance.measure) {
#       performance.mark(markEnd);
#       performance.measure(getMeasureName(markEnd), NAVIGATION_START, markEnd);
#     }
#   }
# }
#
# var imgOnLoadListenerEager = createOnLoadListener("eagerLoadedPhotoLoaded");
# var imgOnLoadListenerLazy = createOnLoadListener("firstLazyLoadedPhotoLoaded");
#
# function listenToImgOnLoad (handler) {
#   return function(imgEl) {
#     if (imgEl.complete) {
#       handler();
#     } else {
#       imgEl.addEventListener('load', handler, { once: true });
#     }
#   }
# }
#
# // we select one specific grid to avoid adding listeners for duplicate photos across all 3 grids.
# var masonryGrid = document.querySelector('[data-test="masonry-grid-count-three"]');
# var eagerImgs = masonryGrid ? masonryGrid.querySelectorAll('[data-perf="eager-loaded-img"]') : [];
# var lazyImg = masonryGrid ? masonryGrid.querySelector('[data-perf="lazy-loaded-img"]') : null;
#
# eagerImgs.forEach(listenToImgOnLoad(imgOnLoadListenerEager));
# if (lazyImg !== null) {
#   listenToImgOnLoad(imgOnLoadListenerLazy)(lazyImg);
# }
# })();
# </script><script>(()=>{"use strict";var e={},a={};function c(d){var t=a[d];if(void 0!==t)return t.exports;var o=a[d]={id:d,loaded:!1,exports:{}};return e[d].call(o.exports,o,o.exports,c),o.loaded=!0,o.exports}c.m=e,(()=>{var e=[];c.O=(a,d,t,o)=>{if(d){o=o||0;for(var b=e.length;b>0&&e[b-1][2]>o;b--)e[b]=e[b-1];e[b]=[d,t,o];return}for(var r=1/0,b=0;b<e.length;b++){for(var[d,t,o]=e[b],f=!0,u=0;u<d.length;u++)r>=o&&Object.keys(c.O).every(e=>c.O[e](d[u]))?d.splice(u--,1):(f=!1,o<r&&(r=o));if(f){e.splice(b--,1);var n=t();void 0!==n&&(a=n)}}return a}})(),c.n=e=>{var a=e&&e.__esModule?()=>e.default:()=>e;return c.d(a,{a:a}),a},c.d=(e,a)=>{for(var d in a)c.o(a,d)&&!c.o(e,d)&&Object.defineProperty(e,d,{enumerable:!0,get:a[d]})},c.f={},c.e=e=>Promise.all(Object.keys(c.f).reduce((a,d)=>(c.f[d](e,a),a),[])),c.u=e=>""+(({112:"awards-route",221:"home-module-featured-collection",367:"stats-route",527:"plus-terms-route",558:"visual-search-form",591:"hiring-route",640:"visual-search-route",758:"nav-secondary-menu",1509:"join-route",1605:"search-route",1671:"uploader",1909:"notifications",2076:"apps-route",2114:"press-route",2542:"topics-route",2648:"vertise-route",2677:"search-filters-group",3288:"home-module-trends",4037:"search-filters-modal-content",4354:"plus-route",4408:"home-module-license",4430:"contribute-route",4458:"plus-feed-route",4494:"plus-license-route",4645:"community-route",4747:"collections-feed-route",4840:"topic-submitter",4890:"admin-nav",5007:"photo-footer-info",5015:"asset-route",5153:"briefs-feed-route",5246:"topics-feed-route",5274:"home-module-user-stats",5304:"user-stats-sub-route",5430:"brands-route",5447:"nav-tail-menus",5493:"home-module-plus",5535:"home-module-awards",5562:"login-modal-content",5711:"following-route",5902:"user-hover-card-content",5911:"notifications-modal-content",5923:"contact-us-route",6075:"privacy-policy-route",6248:"app-nav-main-content",6285:"search-photos-route",6591:"edit-modal",6597:"illustrations-feed-route",6602:"say-thanks-card",6736:"user-feed-sub-route",6832:"send-message-modal-content",6838:"brief-submissions-feed-route",6986:"license-route",6990:"mobile-search-filter-button",7282:"education-route",7383:"cookie-policy-route",7395:"photos-feed-route",7584:"search-users-route",7887:"collection-route",8076:"home-module-photo",8268:"history-route",8345:"add-to-collection-modal-content",8390:"home-module-trending-collections",8536:"brands-safety-route",8614:"api-terms-route",8757:"ios-app-route",8837:"app-nav-brief-content",9158:"security-route",9227:"explore-route",9373:"user-route",9385:"trends-route",9490:"terms-and-conditions-route",9573:"brief-route",9582:"about-route",9763:"search-collections-route",9833:"login-route",9935:"user-stats-chart"})[e]||e)+"."+({112:"4a4f93d67ef790a60042",221:"8e21f9d94d73eac5c4e6",246:"e1a3891972ec715c66f6",357:"eb3731b34d27046655f7",367:"c2373949e0c7ba6c4029",425:"23d6ba199ac3685cd01d",432:"402b77d98ac2e886923d",527:"ca6a45cd9261156d4379",549:"f78355b7ff630d84ff19",558:"55b2390a19e0625e6af2",591:"5c1609f6b8ed8ca564ce",640:"7ed46d8e877ff433dc98",758:"e25b5b63f910184200e2",1067:"f83039c01963e8132afc",1263:"6bcea8a349db5b07a66d",1403:"ba760a330439644ae5a7",1439:"de83bb67bf2edb2f1d84",1509:"4036dc5960b1b6bcd152",1605:"ac6137a7e73fed51c1ce",1671:"d6de2a1e765e1f751e1e",1704:"04cc8b48a6522422284e",1899:"34248dee66c1de58fadf",1909:"d0ce4002b55080c3344a",1914:"36c4090e3b7bd40a9b46",2076:"e9cbc03073880dcfeed1",2114:"72a29f28c9431b58b1fb",2282:"5dd1dc552bf9e8b5b7f9",2524:"06c31f9f59f2a688c1b4",2542:"849f0afe9598f293bbaa",2584:"1b55745c181994f4111b",2648:"aeac15541c046bdcc06c",2677:"ef369e8859b4188b13fd",2741:"6dcdc406044b96d3933b",2968:"d45e35926eb1396eebdf",2984:"1ee261681c6d668340ca",2992:"fa2c32bfcc77e7e45de4",3026:"b1490bdbbc441fe78cbb",3121:"f58722d9aea05eb535a2",3207:"54abc7efc1dd2f8c4c73",3214:"5d38f2fdb1a3255302f8",3248:"f34becfe01033c694228",3288:"174de71e0def3c3cbce4",3313:"cc917c0fbd27bd21d75d",3523:"3b1d745f05a788915a34",3565:"fe66469585dd9a1a9d88",3 ...

# %%
import requests

r= requests.get("https://youtu.be/kqtD5dpn9C8?si=QUFdgd7Lh-egUDpk")

print(r.content)
# Out:
# b'<!DOCTYPE html><html style="font-size: 10px;font-family: Roboto, Arial, sans-serif;" lang="bn-BD" darker-dark-theme darker-dark-theme-deprecate system-icons typography typography-spacing><head><script data-id="_gd" nonce="7W6DUNT9hB6R2vbCPQcYew">window.WIZ_global_data = {"MuJWjd":false,"nQyAE":{},"oxN3nb":{"1":false,"641353869":false}};</script><meta http-equiv="X-UA-Compatible" content="IE=edge"/><meta http-equiv="origin-trial" content="ApvK67ociHgr2egd6c2ZjrfPuRs8BHcvSggogIOPQNH7GJ3cVlyJ1NOq/COCdj0+zxskqHt9HgLLETc8qqD+vwsAAABteyJvcmlnaW4iOiJodHRwczovL3lvdXR1YmUuY29tOjQ0MyIsImZlYXR1cmUiOiJQcml2YWN5U2FuZGJveEFkc0FQSXMiLCJleHBpcnkiOjE2OTUxNjc5OTksImlzU3ViZG9tYWluIjp0cnVlfQ=="/><script nonce="7W6DUNT9hB6R2vbCPQcYew">var ytcfg={d:function(){return window.yt&&yt.config_||ytcfg.data_||(ytcfg.data_={})},get:function(k,o){return k in ytcfg.d()?ytcfg.d()[k]:o},set:function(){var a=arguments;if(a.length>1)ytcfg.d()[a[0]]=a[1];else{var k;for(k in a[0])ytcfg.d()[k]=a[0][k]}}};\nwindow.ytcfg.set(\'EMERGENCY_BASE_URL\', \'\\/error_204?t\\x3djserror\\x26level\\x3dERROR\\x26client.name\\x3d1\\x26client.version\\x3d2.20240702.09.00\');</script><script nonce="7W6DUNT9hB6R2vbCPQcYew">(function(){window.yterr=window.yterr||true;window.unhandledErrorMessages={};window.unhandledErrorCount=0;\nwindow.onerror=function(msg,url,line,columnNumber,error){var err;if(error)err=error;else{err=new Error;err.stack="";err.message=msg;err.fileName=url;err.lineNumber=line;if(!isNaN(columnNumber))err["columnNumber"]=columnNumber}var message=String(err.message);if(!err.message||message in window.unhandledErrorMessages||window.unhandledErrorCount>=5)return;window.unhandledErrorCount+=1;window.unhandledErrorMessages[message]=true;var img=new Image;window.emergencyTimeoutImg=img;img.onload=img.onerror=function(){delete window.emergencyTimeoutImg};\nvar combinedLineAndColumn=err.lineNumber;if(!isNaN(err["columnNumber"]))combinedLineAndColumn=combinedLineAndColumn+(":"+err["columnNumber"]);var stack=err.stack||"";var values={"msg":message,"type":err.name,"client.params":"unhandled window error","file":err.fileName,"line":combinedLineAndColumn,"stack":stack.substr(0,500)};var thirdPartyScript=!err.fileName||err.fileName==="<anonymous>"||stack.indexOf("extension://")>=0;var replaced=stack.replace(/https:\\/\\/www.youtube.com\\//g,"");if(replaced.match(/https?:\\/\\/[^/]+\\//))thirdPartyScript=\ntrue;else if(stack.indexOf("trapProp")>=0&&stack.indexOf("trapChain")>=0)thirdPartyScript=true;else if(message.indexOf("redefine non-configurable")>=0)thirdPartyScript=true;var baseUrl=window["ytcfg"].get("EMERGENCY_BASE_URL","https://www.youtube.com/error_204?t=jserror&level=ERROR");var unsupported=message.indexOf("window.customElements is undefined")>=0;if(thirdPartyScript||unsupported)baseUrl=baseUrl.replace("level=ERROR","level=WARNING");var parts=[baseUrl];var key;for(key in values){var value=\nvalues[key];if(value)parts.push(key+"="+encodeURIComponent(value))}img.src=parts.join("&")};\n(function(){function _getExtendedNativePrototype(tag){var p=this._nativePrototypes[tag];if(!p){p=Object.create(this.getNativePrototype(tag));var p$=Object.getOwnPropertyNames(window["Polymer"].Base);var i=0;var n=void 0;for(;i<p$.length&&(n=p$[i]);i++)if(!window["Polymer"].BaseDescriptors[n])try{p[n]=window["Polymer"].Base[n]}catch(e){throw new Error("Error while copying property: "+n+". Tag is "+tag);}try{Object.defineProperties(p,window["Polymer"].BaseDescriptors)}catch(e){throw new Error("Polymer define property failed for "+\nObject.keys(p));}this._nativePrototypes[tag]=p}return p}function handlePolymerError(msg){window.onerror(msg,window.location.href,0,0,new Error(Array.prototype.join.call(arguments,",")))}var origPolymer=window["Polymer"];var newPolymer=function(config){if(!origPolymer._ytIntercepted&&window["Polymer"].Base){origPolymer._ytIntercepted=true;window["Polymer"].Base._getExtendedNativePrototype=_getExtendedNativePrototype;window["Polymer"].Base._error=handlePolymerError;w ...
